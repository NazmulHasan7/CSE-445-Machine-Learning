# %% [markdown]
# # Feature Selection
#
#  - There are several benefits of feature selection
#  - Some are given below:
#      - Reduces overfitting: Less redundant data means less opportunity to make decisions based on noise.
#      - Improves Accuracy: Less misleading data means modeling accuracy improves.
#      - Reduces Training Time: Less data means that algorithms train faster.
#  - In this notebook, we discuss several feature selection algorithms
#      - Algorithm 1: Dropping Constant Features using Variance Threshold Technique
#      - Algorithm 2: Feature Selection using Pearson's correlation
#      - Algorithm 3: Feature Selection using Information Gain
#      - Algorithm 4: Feature Selection using RFECV (Recursive Feature Elimination with Cross Validation)

# %% [markdown]
# # Algorithm 1 - Dropping Constant Features using Variance Threshold Technique

# %%
import pandas as pd
# Make a dataframe for the following data

data = pd.DataFrame({"A":[1,2,4,1,2,4],
                     "B":[4,5,6,7,8,9],
                     "C":[0,0,0,0,0,0],
                     "D":[1,1,1,1,1,1]}
                    )
data
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  5  0  1
# 2  4  6  0  1
# 3  1  7  0  1
# 4  2  8  0  1
# 5  4  9  0  1

# %% [markdown]
# # Variance Threshold:
#
#  - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html
#  - class sklearn.feature_selection.VarianceThreshold(threshold=0.0)
#  - Feature selector that removes all low-variance features.
#  - This feature selection algorithm looks only at the features (X), not the desired outputs (y), and can thus be used for unsupervised learning.

# %%
from sklearn.feature_selection import VarianceThreshold
# By default, the threshold = 0 i.e. it will remove the zero-variance threshold
var_thresh = VarianceThreshold() # by default the threshold = 0
var_thresh.fit(data)
# Out:
# VarianceThreshold()

# %%
var_thresh.get_support()
# Out:
# array([ True,  True, False, False])

# %%
print("All features: ", data.columns)
print("Features Selected: ", data.columns[var_thresh.get_support()])
# Out:
# All features:  Index(['A', 'B', 'C', 'D'], dtype='object')
# Features Selected:  Index(['A', 'B'], dtype='object')

# %%
# the following code drops the columns based on the variance threshold algorithm
selected_columns = data.columns[var_thresh.get_support()]
for cols in data.columns:
    if cols not in selected_columns:
        data.drop(columns = cols, inplace = True)

# %%
data
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  4  6
# 3  1  7
# 4  2  8
# 5  4  9

# %% [markdown]
# # Removing zero variance features using raw python code

# %%
data = pd.DataFrame({"A":[1,2,4,1,2,4],
                     "B":[4,5,6,7,8,9],
                     "C":[0,0,0,0,0,0],
                     "D":[1,1,1,1,1,1]}
                    )
data
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  5  0  1
# 2  4  6  0  1
# 3  1  7  0  1
# 4  2  8  0  1
# 5  4  9  0  1

# %%
selected_features = []
for cols in data.columns:
    if len(data[cols].unique()) > 1:
        selected_features.append(cols)
selected_features
# Out:
# ['A', 'B']

# %% [markdown]
# # Algorithm 2 - Feature Selection with Pearson's correlation

# %% [markdown]
# # Idea
#
#  - Highly correlated features with the target variable are important features
#  - High correlation between features, (say over 90% or over 80%) indicate the existence of duplicate features.
#  - In case of duplicate features, we do not need to take all the features but one one of them would suffice

# %%
## Let's load the Absenteeism dataset

df = pd.read_excel('absenteeism.xls')
print(df.shape)
df.head()
# Out:
# (740, 21)
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
#
#     Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0  33.0                239554.0  ...                   0.0        1.0  2.0
# 1  50.0                239554.0  ...                   1.0        1.0  1.0
# 2  38.0                239554.0  ...                   0.0        1.0  0.0
# 3  39.0                239554.0  ...                   0.0        1.0  2.0
# 4  33.0                239554.0  ...                   0.0        1.0  2.0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0             1.0            0.0  1.0    90.0   172.0             30.0
# 1             1.0            0.0  0.0    98.0   178.0             31.0
# 2             1.0            0.0  0.0    89.0   170.0             31.0
# 3             1.0            1.0  0.0    68.0   168.0             24.0
# 4             1.0            0.0  1.0    90.0   172.0             30.0
#
#    Absenteeism time in hours
# 0                        4.0
# 1                        0.0
# 2                        2.0
# 3                        4.0
# 4                        2.0
#
# [5 rows x 21 columns]

# %%
df.dropna(inplace = True)
print(df.shape)
# Out:
# (639, 21)

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
# Separate the independent (X) and dependent (y) features
y = df['Absenteeism time in hours']
X = df.drop(columns = 'Absenteeism time in hours')

# %%
X.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0  33.0                239554.0        97.0                   0.0        1.0
# 1  50.0                239554.0        97.0                   1.0        1.0
# 2  38.0                239554.0        97.0                   0.0        1.0
# 3  39.0                239554.0        97.0                   0.0        1.0
# 4  33.0                239554.0        97.0                   0.0        1.0
#
#    Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index
# 0  2.0             1.0            0.0  1.0    90.0   172.0             30.0
# 1  1.0             1.0            0.0  0.0    98.0   178.0             31.0
# 2  0.0             1.0            0.0  0.0    89.0   170.0             31.0
# 3  2.0             1.0            1.0  0.0    68.0   168.0             24.0
# 4  2.0             1.0            0.0  1.0    90.0   172.0             30.0

# %%
y.head()
# Out:
# 0    4.0
# 1    0.0
# 2    2.0
# 3    4.0
# 4    2.0
# Name: Absenteeism time in hours, dtype: float64

# %%
# Let's first drop the feature id as it is a personal identifier
# Let's split the data into train and test set
# Note that correlation will be done only on the training dataset
from sklearn.model_selection import train_test_split
X.drop(columns = "ID", inplace = True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

# %%
# let's import the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X_train.head()
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 645                27.0               3.0                6        2
# 588                27.0               2.0                4        2
# 51                  0.0               9.0                2        4
# 54                  0.0               9.0                3        4
# 88                 23.0              11.0                4        4
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 645                   179.0                             51.0          18.0
# 588                   179.0                             51.0          18.0
# 51                    225.0                             26.0           9.0
# 54                    289.0                             36.0          13.0
# 88                    225.0                             26.0           9.0
#
#       Age  Work load Average/day   Hit target  Disciplinary failure  \
# 645  38.0                222196.0        99.0                   0.0
# 588  38.0                264249.0        97.0                   0.0
# 51   28.0                241476.0        92.0                   1.0
# 54   33.0                241476.0        92.0                   1.0
# 88   28.0                306345.0        93.0                   0.0
#
#      Education  Son  Social drinker  Social smoker  Pet  Weight  Height  \
# 645        1.0  0.0             1.0            0.0  0.0    89.0   170.0
# 588        1.0  0.0             1.0            0.0  0.0    89.0   170.0
# 51         1.0  1.0             0.0            0.0  2.0    69.0   169.0
# 54         1.0  2.0             1.0            0.0  1.0    90.0   172.0
# 88         1.0  1.0             0.0            0.0  2.0    69.0   169.0
#
#      Body mass index
# 645             31.0
# 588             31.0
# 51              24.0
# 54              30.0
# 88              24.0

# %%
# Let's find the feature correlations

corr = X_train.corr()
corr

# Note that the correlation values lie between -1 and +1
# A correlation value close to -1 indicates a strong negative linear correlation
# A correlation value close to +1 indicates a strong positive linear correlation
# A correlation value close to 0 indicates no linear correlation
# Out:
#                                  Reason for absence  Month of absence  \
# Reason for absence                         1.000000         -0.082365
# Month of absence                          -0.082365          1.000000
# Day of the week                            0.139880         -0.042561
# Seasons                                   -0.141645          0.394502
# Transportation expense                    -0.108721          0.126988
# Distance from Residence to Work            0.187522         -0.039480
# Service time                               0.099970         -0.066917
# Age                                       -0.044458          0.009941
# Work load Average/day                     -0.141390         -0.110607
# Hit target                                 0.032852         -0.474779
# Disciplinary failure                      -0.509388          0.111391
# Education                                 -0.050810         -0.025659
# Son                                       -0.056189          0.049621
# Social drinker                             0.121760          0.005340
# Social smoker                             -0.079242         -0.028218
# Pet                                       -0.066426          0.042912
# Weight                                     0.010671          0.024668
# Height                                    -0.090484         -0.065343
# Body mass index                            0.053957          0.048347
#
#                                  Day of the week   Seasons  \
# Reason for absence                      0.139880 -0.141645
# Month of absence                       -0.042561  0.394502
# Day of the week                         1.000000  0.048180
# Seasons                                 0.048180  1.000000
# Transportation expense                  0.010392  0.049554
# Distance from Residence to Work         0.096749 -0.065337
# Service time                            0.021794 -0.013556
# Age                                     0.013481 -0.014083
# Work load Average/day                   0.041432  0.142321
# Hit target                              0.012381 -0.063809
# Disciplinary failure                   -0.037094  0.126736
# Education                               0.082978  0.032900
# Son                                     0.091858  0.000724
# Social drinker                          0.027641 -0.080454
# Social smoker                           0.040792 -0.020047
# Pet                                    -0.029048  0.012827
# Weight                                 -0.145997 -0.010173
# Height                                 -0.064513 -0.048552
# Body mass index                        -0.128202  0.011707
#
#                                  Transportation expense  \
# Reason for absence                            -0.108721
# Month of absence                               0.126988
# Day of the week                                0.010392
# Seasons                                        0.049554
# Transportation expense                         1.000000
# Distance from Residence to Work                0.224753
# Service time                                  -0.347612
# Age                                           -0.202000
# Work load Average/day                          0.053691
# Hit target                                    -0.079950
# Disciplinary failure                           0.111324
# Education                                     -0.057344
# Son                                            0.369093
# Social drinker                                 0.117376
# Social smoker                                  0.045165
# Pet                                            0.338960
# Weight                                        -0.209951
# Height                                        -0.186753
# Body mass index                               -0.141915
#
#                                  Distance from Residence to Work  \
# Reason for absence                                      0.187522
# Month of absence                                       -0.039480
# Day of the week                                         0.096749
# Seasons                                                -0.065337
# Transportation expense                                  0.224753
# Distance from Residence to Work                         1.000000
# Service time                                            0.162415
# Age                                                    -0.127041
# Work load Average/day                                  -0.024887
# Hit target                                             -0.016185
# Disciplinary failure                                   -0.042408
# Education                                              -0.251078
# Son                                                     0.040158
# Social drinker                                          0.458648
# Social smoker                                          -0.080751
# Pet                                                     0.190246
# Weight                                                 -0.029693
# Height                                                 -0.350742
# Body mass index                                         0.129575
#
#                                  Service time       Age  \
# Reason for absence                   0.099970 -0.044458
# Month of absence                    -0.066917  0.009941
# Day of the week                      0.021794  0.013481
# Seasons                             -0.013556 -0.014083
# Transportation expense              -0.347612 -0.202000
# Distance from Residence to Work      0.162415 -0.127041
# Service time                         1.000000  0.652352
# Age                                  0.652352  1.000000
# Work load Average/day                0.003865 -0.051574
# Hit target                          -0.021079 -0.048063
# Disciplinary failure                -0.012317  0.088810
# Education                           -0.257400 -0.250159
# Son                                 -0.055222  0.052568
# Social drinker                       0.385568  0.231321
# Social smoker                        0.099249  0.137464
# Pet                                 -0.455354 -0.227388
# Weight                               0.465684  0.418176
# Height                              -0.064983 -0.066631
# Body mass index                      0.512653  0.470392
#
#                                  Work load Average/day   Hit target  \
# Reason for absence                            -0.141390    0.032852
# Month of absence                              -0.110607   -0.474779
# Day of the week                                0.041432    0.012381
# Seasons                                        0.142321   -0.063809
# Transportation expense                         0.053691   -0.079950
# Distance from Residence to Work               -0.024887   -0.016185
# Service time                                   0.003865   -0.021079
# Age                                           -0.051574   -0.048063
# Work load Average/day                          1.000000   -0.104236
# Hit target                                    -0.104236    1.000000
# Disciplinary failure                           0.031562   -0.128949
# Education                                     -0.079139    0.123075
# Son                                            0.025612   -0.019617
# Social drinker                                -0.033912   -0.077325
# Social smoker                                  0.040739    0.064472
# Pet                                            0.028977   -0.011375
# Weight                                        -0.024456   -0.059414
# Height                                         0.065756    0.115097
# Body mass index                               -0.060561   -0.109362
#
#                                  Disciplinary failure  Education       Son  \
# Reason for absence                          -0.509388  -0.050810 -0.056189
# Month of absence                             0.111391  -0.025659  0.049621
# Day of the week                             -0.037094   0.082978  0.091858
# Seasons                                      0.126736   0.032900  0.000724
# Transportation expense                       0.111324  -0.057344  0.369093
# Distance from Residence to Work             -0.042408  -0.251078  0.040158
# Service time                                -0.012317  -0.257400 -0.055222
# Age                                          0.088810  -0.250159  0.052568
# Work load Average/day                        0.031562  -0.079139  0.025612
# Hit target                                  -0.128949   0.123075 -0.019617
# Disciplinary failure                         1.000000  -0.064107  0.056510
# Education                                   -0.064107   1.000000 -0.200741
# Son                                          0.056510  -0.200741  1.000000
# Social drinker                               0.021469  -0.419723  0.191528
# Social smoker                                0.081115   0.030000  0.173198
# Pet                                          0.027295  -0.030670  0.117211
# Weight                                       0.049689  -0.325039 -0.117418
# Height                                      -0.008680   0.113592 -0.004935
# Body mass index                              0.053245  -0.392544 -0.124945
#
#                                  Social drinker  Social smoker       Pet  \
# Reason for absence                     0.121760      -0.079242 -0.066426
# Month of absence                       0.005340      -0.028218  0.042912
# Day of the week                        0.027641       0.040792 -0.029048
# Seasons                               -0.080454      -0.020047  0.012827
# Transportation expense                 0.117376       0.045165  0.338960
# Distance from Residence to Work        0.458648      -0.080751  0.190246
# Service time                           0.385568       0.099249 -0.455354
# Age                                    0.231321       0.137464 -0.227388
# Work load Average/day                 -0.033912       0.040739  0.028977
# Hit target                            -0.077325       0.064472 -0.011375
# Disciplinary failure                   0.021469       0.081115  0.027295
# Education                             -0.419723       0.030000 -0.030670
# Son                                    0.191528       0.173198  0.117211
# Social drinker                         1.000000      -0.116751 -0.113798
# Social smoker                         -0.116751       1.000000  0.097919
# Pet                                   -0.113798       0.097919  1.000000
# Weight                                 0.388315      -0.192105 -0.120378
# Height                                 0.164722      -0.023195 -0.081397
# Body mass index                        0.331880      -0.178117 -0.101664
#
#                                    Weight    Height  Body mass index
# Reason for absence               0.010671 -0.090484         0.053957
# Month of absence                 0.024668 -0.065343         0.048347
# Day of the week                 -0.145997 -0.064513        -0.128202
# Seasons                         -0.010173 -0.048552         0.011707
# Transportation expense          -0.209951 -0.186753        -0.141915
# Distance from Residence to Work -0.029693 -0.350742         0.129575
# Service time                     0.465684 -0.064983         0.512653
# Age                              0.418176 -0.066631         0.470392
# Work load Average/day           -0.024456  0.065756        -0.060561
# Hit target                      -0.059414  0.115097        -0.109362
# Disciplinary failure             0.049689 -0.008680         0.053245
# Education                       -0.325039  0.113592        -0.392544
# Son                             -0.117418 -0.004935        -0.124945
# Social drinker                   0.388315  0.164722         0.331880
# Social smoker                   -0.192105 -0.023195        -0.178117
# Pet                             -0.120378 -0.081397        -0.101664
# Weight                           1.000000  0.294210         0.904926
# Height                           0.294210  1.000000        -0.132049
# Body mass index                  0.904926 -0.132049         1.000000

# %%
# A good way to visualize correlation is using a heatmap
plt.figure(figsize = (12,10))
sns.heatmap(corr, annot = True, cmap = "seismic");
# A link to choose different cmaps: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
# use of the mask 
import numpy as np
mask1 = np.triu(np.ones_like(corr, dtype=bool))
mask2 = np.tril(np.ones_like(corr, dtype=bool))
plt.figure(figsize = (12,10))
sns.heatmap(corr, annot = True, cmap = "seismic", mask = mask1);

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is highly correlated with another feature

def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of the redundant columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.9) # 85% is a good value of the threshold
print(len(corr_features))
print(corr_features)
# Out:
# 1
# {'Body mass index'}

# %% [markdown]
# # Algorithm 3 - Feature Selection using Information Gain

# %%
# Let's read a dataset [PIMA Indians Diabetes Dataset]
df = pd.read_csv('diabetes.csv')
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df = df.dropna()
print("Shape: ", df.shape)
df["Outcome"].value_counts()
# Out:
# Shape:  (768, 9)
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# Let's separate the independent (X) and dependent (y) variables
y = df['Outcome']
X = df.drop(columns = 'Outcome')
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
# Split the dataset into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2 )

# %%
# URL: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_classif.html
# Estimate mutual information for a discrete target variable.
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. 
# It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
from sklearn.feature_selection import mutual_info_classif

mutual_info = mutual_info_classif(X_train, y_train, random_state = 20)
mutual_info
# Out:
# array([0.04738501, 0.12236251, 0.01140381, 0.01226112, 0.04213022,
#        0.0729025 , 0.00461064, 0.07182349])

# %%
print(len(mutual_info))
print(X_train.shape)
# Out:
# 8
# (614, 8)

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# Glucose                     0.122363
# BMI                         0.072903
# Age                         0.071823
# Pregnancies                 0.047385
# Insulin                     0.042130
# SkinThickness               0.012261
# BloodPressure               0.011404
# DiabetesPedigreeFunction    0.004611
# dtype: float64

# %%
plt.figure(figsize = (20, 8))
mutual_info.sort_values(ascending = False).plot.bar();

# %% [markdown]
# # Algorithm 4 - Feature Selection using RFECV (Recursive Feature Elimination with Cross Validation)
#
#  - URL: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#  - URL: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFECV.html
#  - Feature ranking with recursive feature elimination.

# %% [raw]
# RFE: Given an external estimator that assigns weights to features, the goal of recursive feature elimination (RFE) is to select features by recursively considering smaller and smaller sets of features. First, the estimator is trained on the initial set of features and the importance of each feature is obtained either through any specific attribute or callable. Then, the least important features are pruned from current set of features. That procedure is recursively repeated on the pruned set until the desired number of features to select is eventually reached.
#
# RFECV: Feature ranking with recursive feature elimination and cross-validated selection of the best number of features.

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 607            1       92             62             25       41  19.5
# 58             0      146             82              0        0  40.5
# 15             7      100              0              0        0  30.0
# 711            5      126             78             27       22  29.6
# 756            7      137             90             41        0  32.0
# ..           ...      ...            ...            ...      ...   ...
# 726            1      116             78             29      180  36.1
# 565            2       95             54             14       88  26.1
# 290            0       78             88             29       40  36.9
# 291            0      107             62             30       74  36.6
# 75             1        0             48             20        0  24.7
#
#      DiabetesPedigreeFunction  Age
# 607                     0.482   25
# 58                      1.781   44
# 15                      0.484   32
# 711                     0.439   40
# 756                     0.391   39
# ..                        ...  ...
# 726                     0.496   25
# 565                     0.748   22
# 290                     0.434   21
# 291                     0.757   25
# 75                      0.140   22
#
# [614 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

rfc = RandomForestClassifier(random_state=101)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(5), scoring='accuracy')
rfecv.fit(X_train, y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=101), scoring='accuracy')

# %%
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 4

# %%
plt.figure(figsize=(16, 9))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_, color='#303F9F', linewidth=3)
plt.show()

# %%
print(np.where(rfecv.support_ == False)[0])
# Out:
# [0 2 3 4]

# %%
selected_features = X_train.drop(X_train.columns[np.where(rfecv.support_ == False)[0]], axis=1)

# %%
rfecv.estimator_.feature_importances_
# Out:
# array([0.36223864, 0.24380405, 0.19678715, 0.19717016])

# %%
dset = pd.DataFrame()
dset['attr'] = selected_features.columns
dset['importance'] = rfecv.estimator_.feature_importances_
dset = dset.sort_values(by='importance', ascending=False)

plt.figure(figsize=(16, 10))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %%
dset
# Out:
#                        attr  importance
# 0                   Glucose    0.362239
# 1                       BMI    0.243804
# 3                       Age    0.197170
# 2  DiabetesPedigreeFunction    0.196787
